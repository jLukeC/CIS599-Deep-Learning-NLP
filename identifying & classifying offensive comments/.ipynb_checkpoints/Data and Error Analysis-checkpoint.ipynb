# %% [markdown]
# # Examples of each label

# %%
import pandas as pd

labels = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

train = pd.read_csv('data/train.csv')

# %%
train[train['toxic'] == 1].sample(10)["comment_text"]
# Out:
# 37305     "\nWhat kind of bullshit IS that?!  Hamas's SE...
# 19562     Yes. Merry Christmas. You fucking idiot. 86.14...
# 32728     "\n\n INDIA ZINDABAD \n\nINDIA ZINDABAD ! DBAC...
# 6747      Again, not half-jokingly: how do I remove the ...
# 59175     no friends. I spread my legs for money. I work...
# 91911     FUCKING LAMER LOSTING OF MY TIME !!JOADFYH \n\...
# 28886     "\nmaybe you could try and get your message ac...
# 111897    Should we not just refer to them as Blacks? Af...
# 13789     This guy is cool, you are all a bunch of faggy...
# 30319     Oh yeah, I can't wait until this turns into an...
# Name: comment_text, dtype: object

# %%
comments = train[train['toxic'] == 1].sample(10)

# %%
for index, comment in comments.iterrows():
    print(comment[labels])
    print(comment["comment_text"])
    print("------------------")
# Out:
# toxic            1
# severe_toxic     1
# obscene          1
# threat           0
# insult           1
# identity_hate    0
# Name: 93341, dtype: object
# Feydey is a complete fucking fag. I saw that he was harassing you and thought to inform you Fedey is a fucking douche bag through and through. That asshole reverts and deletes whatever the fuck he feels like just to make up for his tiny manhood that can't satisfy any partner, male, female, or shemale. Pricks like him should GTFO wikipedia and just curl up and die in their mother's basements, as is the natural order of things.
# ------------------
# toxic            1
# severe_toxic     0
# obscene          1
# threat           0
# insult           1
# identity_hate    0
# Name: 101958, dtype: object
# Alright, well do us all a favor. FUCK OFF! No one wants to read these articles and see that citation bullshit all over the page. That stuff has been there for years and no one gave a rats ass until now. Seriously dude, fuck off.
# ...

# %%
print_comments(train[train['identity_hate'] == 1].sample(10))
# Out:
# toxic            1
# severe_toxic     1
# obscene          1
# threat           0
# insult           1
# identity_hate    1
# Name: 12559, dtype: object
# FUCK THE POOR BRITAIN IS SHITTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# ------------------
# toxic            1
# severe_toxic     0
# obscene          1
# threat           1
# insult           1
# identity_hate    1
# Name: 95455, dtype: object
# With Regards to Your Recent Thoughtful Epistle...
#
# Go get fucked and maybe you will not be so goddamned gay. Otherwise, go eat a bag of hell and drop dead.
# ------------------
# toxic            1
# severe_toxic     0
# obscene          1
# threat           0
# insult           1
# identity_hate    1
# Name: 54005, dtype: object
# Web of Trust
#
# It's not my fault, some gay little faggot vandal, kept editting the article, and removing the link to the OFFICIAL WEBSITE of the damn thing, and adding like 30 spam links, that have nothing to do with WOT.4.244.36.149
# ------------------
# ...

# %%
print_comments(train[train['threat'] == 1].sample(10))
# Out:
# toxic            1
# severe_toxic     1
# obscene          1
# threat           1
# insult           1
# identity_hate    0
# Name: 97250, dtype: object
# you're hot
#
# i will rape you ;)
# ------------------
# toxic            1
# severe_toxic     1
# obscene          1
# threat           1
# insult           1
# identity_hate    0
# Name: 99815, dtype: object
# HOPE YOUR HEAD GETS CUT OFF AND SOMEONE WIPS THERE ASS WITH IT AND THEN STABS YOU IN YOUR HEART
# ------------------
# toxic            1
# severe_toxic     0
# obscene          0
# threat           1
# insult           0
# identity_hate    0
# Name: 17170, dtype: object
# EVula you may have blocked my friends but you wont block me or you will be sorry. You are doomed EVula. I will hunt you down and brutally murder you. Then I will throw your body into the ocean. How sad is it knowing you will soon be fishfood?
# ------------------
# toxic            1
# severe_toxic     1
# obscene          1
# threat           1
# ...

# %%
print_comments(train.sample(10))
# Out:
# toxic            0
# severe_toxic     0
# obscene          0
# threat           0
# insult           0
# identity_hate    0
# Name: 124483, dtype: object
# "
#  I don't understand the point of the edit war that you are waging here. Are you trying to say that Armenians fought with some unknown Tatar people, who had nothing to do with Azerbaijanis? Then what happened to those Tatars? Where are they now? What exactly is your point? Please explain. Citing old memoirs and rolling back the article is not acceptable, you should refer to secondary modern sources for explanation of who those Tatars were. master "
# ------------------
# toxic            0
# severe_toxic     0
# obscene          0
# threat           0
# insult           0
# identity_hate    0
# Name: 117773, dtype: object
# ...

# %%
 y
